# %%
import os
import pandas as pd

# %%
experiments = ["melon"] # Choose: ['square', 'random', 'chirp']
runs = [1, 2, 3]
df_real_dict = {}

for experiment in experiments:
    file_name = f'{experiment}_20251017'
    for run in runs:
        try:
            file_name_real = f'{file_name}_run{run}.csv'
            df_real = pd.read_csv(os.path.join('../data/test/', file_name_real))
            # Store dynamically
            df_real_dict[f'{experiment}_run{run}'] = df_real
        except Exception as e:
            print(e)
            continue
# Out:
# [Errno 2] No such file or directory: '../data/real/processed/test/melon_20251017_run1.csv'
# [Errno 2] No such file or directory: '../data/real/processed/test/melon_20251017_run2.csv'
# [Errno 2] No such file or directory: '../data/real/processed/test/melon_20251017_run3.csv'

# %%
total = 0
for (key, df) in df_real_dict.items():
    total += df.shape[0]

# %%
# pd.DataFrame({"columns": df_real.columns}).to_excel("columns.xlsx", index=False)
